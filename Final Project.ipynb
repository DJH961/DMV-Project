# %% [markdown]
# # Final Project

# %%
import pandas as pd

listings = pd.read_csv('listings2024.csv')
reviews = pd.read_csv('reviews2024.csv')
calendar = pd.read_csv('calendar2024.csv')

# %%
# Summary for listings dataset
print("Listings Dataset Summary:")
print(listings.info())
print(listings.describe(include='all'))

# Summary for reviews dataset
print("\nReviews Dataset Summary:")
print(reviews.info())
print(reviews.describe(include='all'))

# Summary for calendar dataset
print("\nCalendar Dataset Summary:")
print(calendar.info())
print(calendar.describe(include='all'))
# Out:
# Listings Dataset Summary:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20909 entries, 0 to 20908
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            20909 non-null  int64
#  1   listing_url                                   20909 non-null  object
#  2   scrape_id                                     20909 non-null  int64
#  3   last_scraped                                  20909 non-null  object
#  4   source                                        20909 non-null  object
#  5   name                                          20909 non-null  object
#  6   description                                   20235 non-null  object
#  7   neighborhood_overview                         8984 non-null   object
#  8   picture_url                                   20909 non-null  object
# ...
